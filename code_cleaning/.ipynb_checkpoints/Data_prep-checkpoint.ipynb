# %%
#import modules for analyzing ,plotting, and formatting
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import seaborn as sns
import sqlite3
import os
import folium

# %%
os.chdir(r"C:\Users\5luca\Documents\Python\Projects\wildfire_ca\data")
df = pd.read_csv('California_Fire_Incidents.csv')
weather = pd.read_csv('weather_ca.csv')
df.head()
# Out:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1      30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2      27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3      27440.0   False                              Tahoe National Forest
# 4      24251.0   False                       Ventura County Fire/CAL FIRE
#
#    AirTankers  ArchiveYear  CalFireIncident  \
# 0         NaN         2013             True
# 1         NaN         2013             True
# 2         NaN         2013             True
# 3         NaN         2013            False
# 4         NaN         2013             True
#
#                             CanonicalUrl  \
# 0         /incidents/2013/8/17/rim-fire/
# 1  /incidents/2013/5/30/powerhouse-fire/
# 2    /incidents/2013/7/15/mountain-fire/
# 3    /incidents/2013/8/10/american-fire/
# ...

# %%
weather.head()
# Out:
#    Unnamed: 0   EventId  Type  Severity      StartTime(UTC)  \
# 0      102527  W-103895   Fog  Moderate 2016-01-02 00:53:00
# 1      102528  W-103896  Rain     Light 2016-01-04 02:53:00
# 2      102529  W-103897  Rain     Light 2016-01-04 11:53:00
# 3      102530  W-103898  Rain     Light 2016-01-05 06:53:00
# 4      102531  W-103899  Rain  Moderate 2016-01-05 12:48:00
#
#          EndTime(UTC)  Precipitation(in)    TimeZone AirportCode  LocationLat  \
# 0 2016-01-02 01:53:00               0.00  US/Pacific        KWVI      36.9394
# 1 2016-01-04 05:53:00               0.02  US/Pacific        KWVI      36.9394
# 2 2016-01-04 17:53:00               0.22  US/Pacific        KWVI      36.9394
# 3 2016-01-05 12:48:00               0.23  US/Pacific        KWVI      36.9394
# 4 2016-01-05 13:50:00               1.11  US/Pacific        KWVI      36.9394
#
#    LocationLng     City      County State  ZipCode
# 0      -121.79  Freedom  Santa Cruz    CA  95019.0
# ...

# %%
#df.info()

# %%
selected_columns = [
    'AcresBurned',
    'ArchiveYear',
    'Counties',
    'Latitude',
    'Longitude',
    'MajorIncident',
    'Name',
]

# %%
df2 = df[selected_columns].copy()
df2
# Out:
#       AcresBurned  ArchiveYear     Counties   Latitude   Longitude  \
# 0        257314.0         2013     Tuolumne  37.857000 -120.086000
# 1         30274.0         2013  Los Angeles  34.585595 -118.423176
# 2         27531.0         2013    Riverside  33.709500 -116.728850
# 3         27440.0         2013       Placer  39.120000 -120.650000
# 4         24251.0         2013      Ventura   0.000000    0.000000
# ...           ...          ...          ...        ...         ...
# 1631          9.0         2019    Riverside  33.827979 -117.499619
# 1632          2.0         2019       Nevada  39.409722 -121.000556
# 1633          NaN         2019         Yolo  38.734634 -121.729691
# 1634          NaN         2019    San Diego  33.351145 -117.403719
# 1635          NaN         2019    Riverside  33.451480 -116.058980
#
#       MajorIncident             Name
# 0             False         Rim Fire
# 1             False  Powerhouse Fire
# 2             False    Mountain Fire
# ...

# %%
weather['StartTime(UTC)']= pd.to_datetime(weather['StartTime(UTC)'])
weather['EndTime(UTC)']= pd.to_datetime(weather['EndTime(UTC)']) 

weather['StartTime(UTC)'].info()

weather_2016 = weather[(weather['StartTime(UTC)'].dt.year == 2016) & (weather['EndTime(UTC)'].dt.year == 2016)]
weather_2016 =  weather_2016.rename(columns={"Precipitation(in)": "Precipitation"})
weather_2016
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 309425 entries, 0 to 309424
# Series name: StartTime(UTC)
# Non-Null Count   Dtype
# --------------   -----
# 309425 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.4 MB
#         Unnamed: 0    EventId           Type  Severity      StartTime(UTC)  \
# 0           102527   W-103895            Fog  Moderate 2016-01-02 00:53:00
# 1           102528   W-103896           Rain     Light 2016-01-04 02:53:00
# 2           102529   W-103897           Rain     Light 2016-01-04 11:53:00
# 3           102530   W-103898           Rain     Light 2016-01-05 06:53:00
# 4           102531   W-103899           Rain  Moderate 2016-01-05 12:48:00
# ...            ...        ...            ...       ...                 ...
# 309334     7461610  W-7559498  Precipitation       UNK 2016-10-16 22:50:00
# 309335     7461611  W-7559499  Precipitation       UNK 2016-10-27 11:55:00
# ...

# %%
df_select = df2[df2.Longitude<-115]
df_select = df_select[(df_select.Latitude<44) & (df_select.Latitude > 30)]
plt.scatter(df_select.Longitude, df_select.Latitude)
plt.grid()
plt.show()

# %%
#Majordf = df_select.iloc[i]['Longitude'== 'True']]
#map
zoom_factor = 5 
radius_scaling = 25

ca_map = folium.Map (location = [36,-120], zoom_start = zoom_factor)

for i in range (0,df_select.shape[0]):
    folium.Circle(
      location=[df_select.iloc[i]['Latitude'], df_select.iloc[i]['Longitude']],
      radius=np.sqrt(df_select.iloc[i]['AcresBurned'])*radius_scaling,
      color='red',
      fill=True,
      fill_color='red'
   ).add_to(ca_map)
ca_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df_select.head()
# Out:
#    AcresBurned  ArchiveYear     Counties   Latitude   Longitude  \
# 0     257314.0         2013     Tuolumne  37.857000 -120.086000
# 1      30274.0         2013  Los Angeles  34.585595 -118.423176
# 2      27531.0         2013    Riverside  33.709500 -116.728850
# 3      27440.0         2013       Placer  39.120000 -120.650000
# 5      22992.0         2013       Fresno  37.279000 -119.318000
#
#    MajorIncident             Name
# 0          False         Rim Fire
# 1          False  Powerhouse Fire
# 2          False    Mountain Fire
# 3          False    American Fire
# 5          False       Aspen Fire

# %%
import plotly.express as px

color_scale = [(0, 'orange'), (1,'red')]
color_scale1 = [(0, 'teal'), (1,'blue')]

fig = px.scatter_mapbox(df_select, 
                        lat= "Latitude", 
                        lon= "Longitude", 
                        color= "MajorIncident",
                        category_orders = {'FIRE_SIZE_CLASS': ['False','True']},
                        color_discrete_sequence=px.colors.qualitative.G10,
                        #size= "AcresBurned",
                        opacity=0.7,
                        zoom=5.5, 
                        height=600,
                        width=600)

fig.add_trace(px.scatter_mapbox(weather_2016,
                                lat="LocationLat",
                                lon="LocationLng",
                                color ='Type',
                                category_orders = {'Type': ['Fog', 'Rain', 'Cold',
                                                            'Snow', 'Storm', 'Precipitation', 
                                                            'Hail']},
                                color_continuous_scale=px.colors.qualitative.T10,
                                #size ='Precipitation(in)',
                                opacity=0.1
                                ).data[0])

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(legend=dict(
    orientation="h",
    yanchor="bottom",
    y=1.02,
    xanchor="right",
    x=1
))
fig.update_layout(legend_tracegroupgap=2)
fig.update_layout(showlegend=True)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="c7268471-7e4e-4572-bf9e-ed71a0642e0a" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7268471-7e4e-4572-bf9e-ed71a0642e0a")) {                    Plotly.newPlot(                        "c7268471-7e4e-4572-bf9e-ed71a0642e0a",                        [{"hovertemplate":"MajorIncident=False<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[37.857,34.585595,33.7095,39.12,37.279,41.32,41.035,33.341,36.208,34.55048,33.62236,38.25108,35.707,34.49149,34.90327,38.774,40.00842,33.894055,41.2415,35.15832,37.96866,34.302,37.160346,38.04993,39.90465,37.116295,34.149,34.35,37.775057,38.729297,34.2,40.012398,39.961309,34.611824,38.67479,38.63987,38.63987,38.34599,38.17693,33.990128,37.436,36.7218,34.419284,36.2
# ...
